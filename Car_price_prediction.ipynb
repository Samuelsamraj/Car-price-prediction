# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import re

# %%
df1 = pd.read_excel('/content/bangalore_cars.xlsx')
df2 = pd.read_excel('/content/chennai_cars.xlsx')
df3 = pd.read_excel('/content/delhi_cars.xlsx')
df4 = pd.read_excel('/content/hyderabad_cars.xlsx')
df5 = pd.read_excel('/content/jaipur_cars.xlsx')
df6 = pd.read_excel('/content/kolkata_cars.xlsx')

# %%
df1['place'] = 'bangalore'

# %%
df1
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 4     {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 1476  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1477  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1478  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1479  {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
# 1480  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# 4     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...                                                 ...
# 1476  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1477  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1478  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1479  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1480  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                         new_car_feature  \
# 0     {'heading': 'Features', 'top': [{'value': 'Pow...
# 1     {'heading': 'Features', 'top': [{'value': 'Pow...
# 2     {'heading': 'Features', 'top': [{'value': 'Pow...
# 3     {'heading': 'Features', 'top': [{'value': 'Pow...
# 4     {'heading': 'Features', 'top': [{'value': 'Pow...
# ...                                                 ...
# 1476  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1477  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1478  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1479  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1480  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                           new_car_specs  \
# 0     {'heading': 'Specifications', 'top': [{'key': ...
# 1     {'heading': 'Specifications', 'top': [{'key': ...
# 2     {'heading': 'Specifications', 'top': [{'key': ...
# 3     {'heading': 'Specifications', 'top': [{'key': ...
# 4     {'heading': 'Specifications', 'top': [{'key': ...
# ...                                                 ...
# 1476  {'heading': 'Specifications', 'top': [{'key': ...
# 1477  {'heading': 'Specifications', 'top': [{'key': ...
# 1478  {'heading': 'Specifications', 'top': [{'key': ...
# 1479  {'heading': 'Specifications', 'top': [{'key': ...
# 1480  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                               car_links      place
# 0     https://www.cardekho.com/used-car-details/used...  bangalore
# 1     https://www.cardekho.com/buy-used-car-details/...  bangalore
# 2     https://www.cardekho.com/used-car-details/used...  bangalore
# 3     https://www.cardekho.com/buy-used-car-details/...  bangalore
# 4     https://www.cardekho.com/used-car-details/used...  bangalore
# ...                                                 ...        ...
# 1476  https://www.cardekho.com/used-car-details/used...  bangalore
# 1477  https://www.cardekho.com/used-car-details/used...  bangalore
# 1478  https://www.cardekho.com/used-car-details/used...  bangalore
# 1479  https://www.cardekho.com/used-car-details/used...  bangalore
# 1480  https://www.cardekho.com/used-car-details/used...  bangalore
#
# [1481 rows x 6 columns]

# %%
df2['place'] = 'chennai'

# %%
df2
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Minivans', 'k...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# ...                                                 ...
# 1414  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1415  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1416  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1417  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1418  {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# 4     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...                                                 ...
# 1414  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1415  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1416  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1417  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1418  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                         new_car_feature  \
# 0     {'heading': 'Features', 'top': [{'value': 'Pow...
# 1     {'heading': 'Features', 'top': [{'value': 'Low...
# 2     {'heading': 'Features', 'top': [{'value': 'Pow...
# 3     {'heading': 'Features', 'top': [{'value': 'Pow...
# 4     {'heading': 'Features', 'top': [{'value': 'Pow...
# ...                                                 ...
# 1414  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1415  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1416  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1417  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1418  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                           new_car_specs  \
# 0     {'heading': 'Specifications', 'top': [{'key': ...
# 1     {'heading': 'Specifications', 'top': [{'key': ...
# 2     {'heading': 'Specifications', 'top': [{'key': ...
# 3     {'heading': 'Specifications', 'top': [{'key': ...
# 4     {'heading': 'Specifications', 'top': [{'key': ...
# ...                                                 ...
# 1414  {'heading': 'Specifications', 'top': [{'key': ...
# 1415  {'heading': 'Specifications', 'top': [{'key': ...
# 1416  {'heading': 'Specifications', 'top': [{'key': ...
# 1417  {'heading': 'Specifications', 'top': [{'key': ...
# 1418  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                               car_links    place
# 0     https://www.cardekho.com/used-car-details/used...  chennai
# 1     https://www.cardekho.com/buy-used-car-details/...  chennai
# 2     https://www.cardekho.com/used-car-details/used...  chennai
# 3     https://www.cardekho.com/buy-used-car-details/...  chennai
# 4     https://www.cardekho.com/used-car-details/used...  chennai
# ...                                                 ...      ...
# 1414  https://www.cardekho.com/used-car-details/used...  chennai
# 1415  https://www.cardekho.com/used-car-details/used...  chennai
# 1416  https://www.cardekho.com/used-car-details/used...  chennai
# 1417  https://www.cardekho.com/used-car-details/used...  chennai
# 1418  https://www.cardekho.com/used-car-details/used...  chennai
#
# [1419 rows x 6 columns]

# %%
df3['place'] = 'delhi'

# %%
df3
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 1480  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1481  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1482  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1483  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1484  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# 4     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...                                                 ...
# 1480  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1481  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1482  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1483  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1484  {'heading': 'Car overview', 'top': [{'key': 'I...
#
#                                         new_car_feature  \
# 0     {'heading': 'Features', 'top': [{'value': 'Pow...
# 1     {'heading': 'Features', 'top': [{'value': 'Pow...
# 2     {'heading': 'Features', 'top': [{'value': 'Pow...
# 3     {'heading': 'Features', 'top': [{'value': 'Pow...
# 4     {'heading': 'Features', 'top': [{'value': 'Pow...
# ...                                                 ...
# 1480  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1481  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1482  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1483  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1484  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                           new_car_specs  \
# 0     {'heading': 'Specifications', 'top': [{'key': ...
# 1     {'heading': 'Specifications', 'top': [{'key': ...
# 2     {'heading': 'Specifications', 'top': [{'key': ...
# 3     {'heading': 'Specifications', 'top': [{'key': ...
# 4     {'heading': 'Specifications', 'top': [{'key': ...
# ...                                                 ...
# 1480  {'heading': 'Specifications', 'top': [{'key': ...
# 1481  {'heading': 'Specifications', 'top': [{'key': ...
# 1482  {'heading': 'Specifications', 'top': [{'key': ...
# 1483  {'heading': 'Specifications', 'top': [{'key': ...
# 1484  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                               car_links  place
# 0     https://www.cardekho.com/used-car-details/used...  delhi
# 1     https://www.cardekho.com/buy-used-car-details/...  delhi
# 2     https://www.cardekho.com/used-car-details/used...  delhi
# 3     https://www.cardekho.com/buy-used-car-details/...  delhi
# 4     https://www.cardekho.com/used-car-details/used...  delhi
# ...                                                 ...    ...
# 1480  https://www.cardekho.com/used-car-details/used...  delhi
# 1481  https://www.cardekho.com/used-car-details/used...  delhi
# 1482  https://www.cardekho.com/used-car-details/used...  delhi
# 1483  https://www.cardekho.com/used-car-details/used...  delhi
# 1484  https://www.cardekho.com/used-car-details/used...  delhi
#
# [1485 rows x 6 columns]

# %%
df4['place'] = 'hyderabad'

# %%
df4
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 
{'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 4  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1  {'heading': 'Car overview', 'top': [{'key': 'R...
# 2  {'heading': 'Car overview', 'top': [{'key': 'R...
# 3  {'heading': 'Car overview', 'top': [{'key': 'R...
# 4  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1  {'heading': 'Features', 'top': [{'value': 'Pow...
# 2  {'heading': 'Features', 'top': [{'value': 'Pow...
# 3  {'heading': 'Features', 'top': [{'value': 'Pow...
# 4  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# 0  {'heading': 'Specifications', 'top': [{'key': ...
# 1  {'heading': 'Specifications', 'top': [{'key': ...
# 2  {'heading': 'Specifications', 'top': [{'key': ...
# 3  {'heading': 'Specifications', 'top': [{'key': ...
# 4  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                            car_links      place
# 0  https://www.cardekho.com/used-car-details/used...  bangalore
# 1  https://www.cardekho.com/buy-used-car-details/...  bangalore
# 2  https://www.cardekho.com/used-car-details/used...  bangalore
# 3  https://www.cardekho.com/buy-used-car-details/...  bangalore
# 4  https://www.cardekho.com/used-car-details/used...  bangalore

# %%
combined_df.tail()
# Out:
#                                          new_car_detail  \
# 8364  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 8365  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 8366  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 8367  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 8368  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                        new_car_overview  \
# 8364  {'heading': 'Car overview', 'top': [{'key': 'R...
# 8365  {'heading': 'Car overview', 'top': [{'key': 'R...
# 8366  {'heading': 'Car overview', 'top': [{'key': 'R...
# 8367  {'heading': 'Car overview', 'top': [{'key': 'R...
# 8368  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                         new_car_feature  \
# 8364  {'heading': 'Features', 'top': [{'value': 'Pow...
# 8365  {'heading': 'Features', 'top': [{'value': 'Pow...
# 8366  {'heading': 'Features', 'top': [{'value': 'Pow...
# 8367  {'heading': 'Features', 'top': [{'value': 'Pow...
# 8368  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                           new_car_specs  \
# 8364  {'heading': 'Specifications', 'top': [{'key': ...
# 8365  {'heading': 'Specifications', 'top': [{'key': ...
# 8366  {'heading': 'Specifications', 'top': [{'key': ...
# 8367  {'heading': 'Specifications', 'top': [{'key': ...
# 8368  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                               car_links    place
# 8364  https://www.cardekho.com/used-car-details/used...  kolkata
# 8365  https://www.cardekho.com/used-car-details/used...  kolkata
# 8366  https://www.cardekho.com/used-car-details/used...  kolkata
# 8367  https://www.cardekho.com/used-car-details/used...  kolkata
# 8368  https://www.cardekho.com/used-car-details/used...  kolkata

# %%
combined_df.shape
# Out:
# (8369, 6)

# %%
combined_df.new_car_detail[0]
# Out:
# "{'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', 'km': '1,20,000', 'transmission': 'Manual', 'ownerNo': 3, 'owner': '3rd Owner', 'oem': 'Maruti', 'model': 'Maruti Celerio', 'modelYear': 2015, 'centralVariantId': 3979, 'variantName': 'VXI', 'price': '₹ 4 Lakh', 'priceActual': '', 'priceSaving': '', 'priceFixedText': None, 'trendingText': {'imgUrl': 'https://stimg.cardekho.com/used-cars/common/icons/trending.svg', 'heading': 'Trending Car!', 'desc': 'High chances of sale in next 6 days'}}"

# %%
new_car_detail = pd.DataFrame(combined_df.new_car_detail.apply(eval).tolist())
new_car_detail['place'] = combined_df.place.to_list()
new_car_detail
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 8364   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 8365   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 8366   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 8367   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 8368   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  centralVariantId  \
# 0            Maruti         Maruti Celerio       2015              3979
# 1              Ford          Ford Ecosport       2018              6087
# 2              Tata             Tata Tiago       2018              2983
# 3           Hyundai          Hyundai Xcent       2014              1867
# 4            Maruti     Maruti SX4 S Cross       2015              4277
# ...             ...                    ...        ...               ...
# 8364         Maruti         Maruti Celerio       2022              8682
# 8365         Maruti        Maruti Alto 800       2014              3943
# 8366  Mercedes-Benz  Mercedes-Benz C-Class       2011              4672
# 8367         Maruti            Maruti Ritz       2012              4144
# 8368        Renault         Renault Duster       2017              5048
#
#                    variantName        price priceActual priceSaving  \
# 0                          VXI     ₹ 4 Lakh
# 1     1.5 Petrol Titanium BSIV  ₹ 8.11 Lakh
# 2              1.2 Revotron XZ  ₹ 5.85 Lakh
# 3           1.2 Kappa S Option  ₹ 4.62 Lakh
# 4                DDiS 200 Zeta  ₹ 7.90 Lakh
# ...                        ...          ...         ...         ...
# 8364                  ZXI BSVI  ₹ 5.10 Lakh
# 8365                       LXI  ₹ 1.80 Lakh
# 8366        C 200 CGI Elegance  ₹ 5.50 Lakh
# 8367                       ZXi  ₹ 1.40 Lakh
# 8368      110PS Diesel RxZ AWD     ₹ 5 Lakh
#
#      priceFixedText                                       trendingText  \
# 0              None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 1              None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 2              None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 3              None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 4              None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# ...             ...                                                ...
# 8364           None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 8365           None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 8366           None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 8367           None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 8368           None  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
#
#           place
# 0     bangalore
# 1     bangalore
# 2     bangalore
# 3     bangalore
# 4     bangalore
# ...         ...
# 8364    kolkata
# 8365    kolkata
# 8366    kolkata
# 8367    kolkata
# 8368    kolkata
#
# [8369 rows x 18 columns]

# %%
new_car_detail.drop(['it','ownerNo','centralVariantId','priceActual','priceSaving','priceFixedText','trendingText'],axis = 1,inplace = True)

new_car_detail.km = new_car_detail.km.apply(lambda x : x.replace(",","")).astype(float)

new_car_detail.head()
# Out:
#        ft         bt        km transmission      owner      oem  \
# 0  Petrol  Hatchback  120000.0       Manual  3rd Owner   Maruti
# 1  Petrol        SUV   32706.0       Manual  2nd Owner     Ford
# 2  Petrol  Hatchback   11949.0       Manual  1st Owner     Tata
# 3  Petrol      Sedan   17794.0       Manual  1st Owner  Hyundai
# 4  Diesel        SUV   60000.0       Manual  1st Owner   Maruti
#
#                 model  modelYear               variantName        price  \
# 0      Maruti Celerio       2015                       VXI     ₹ 4 Lakh
# 1       Ford Ecosport       2018  1.5 Petrol Titanium BSIV  ₹ 8.11 Lakh
# 2          Tata Tiago       2018           1.2 Revotron XZ  ₹ 5.85 Lakh
# 3       Hyundai Xcent       2014        1.2 Kappa S Option  ₹ 4.62 Lakh
# 4  Maruti SX4 S Cross       2015             DDiS 200 Zeta  ₹ 7.90 Lakh
#
#        place
# 0  bangalore
# 1  bangalore
# 2  bangalore
# 3  bangalore
# 4  bangalore

# %%
new_car_detail.owner = new_car_detail.owner.apply(lambda owner: int(re.findall(r'\d+',owner)[0]))
new_car_detail.head()
# Out:
#        ft         bt        km transmission  owner      oem  \
# 0  Petrol  Hatchback  120000.0       Manual      3   Maruti
# 1  Petrol        SUV   32706.0       Manual      2     Ford
# 2  Petrol  Hatchback   11949.0       Manual      1     Tata
# 3  Petrol      Sedan   17794.0       Manual      1  Hyundai
# 4  Diesel        SUV   60000.0       Manual      1   Maruti
#
#                 model  modelYear               variantName        price  \
# 0      Maruti Celerio       2015                       VXI     ₹ 4 Lakh
# 1       Ford Ecosport       2018  1.5 Petrol Titanium BSIV  ₹ 8.11 Lakh
# 2          Tata Tiago       2018           1.2 Revotron XZ  ₹ 5.85 Lakh
# 3       Hyundai Xcent       2014        1.2 Kappa S Option  ₹ 4.62 Lakh
# 4  Maruti SX4 S Cross       2015             DDiS 200 Zeta  ₹ 7.90 Lakh
#
#        place
# 0  bangalore
# 1  bangalore
# 2  bangalore
# 3  bangalore
# 4  bangalore

# %%
print("Unique oem present >>>>>>>>>\n\n",sorted(new_car_detail.oem.unique()))
print("\nTotal No of Unique oem >>>>>>",new_car_detail.oem.nunique())
print("\nTotal No of Model >>>>>>>",new_car_detail.model.nunique())
print("\nUnique modelYear >>>>>>>>\n\n",sorted(new_car_detail.modelYear.unique()))
# Out:
# Unique oem present >>>>>>>>>
#
#  ['Audi', 'BMW', 'Chevrolet', 'Citroen', 'Datsun', 'Fiat', 'Ford', 'Hindustan Motors', 'Honda', 'Hyundai', 'Isuzu', 'Jaguar', 'Jeep', 'Kia', 'Land Rover', 'Lexus', 'MG', 'Mahindra', 'Mahindra Renault', 'Mahindra Ssangyong', 'Maruti', 'Mercedes-Benz', 'Mini', 'Mitsubishi', 'Nissan', 'Opel', 'Porsche', 'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo']
#
# Total No of Unique oem >>>>>> 33
#
# Total No of Model >>>>>>> 315
#
# Unique modelYear >>>>>>>>
#
#  [1985, 1995, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]

# %%
price_colvalues = new_car_detail.price.str.replace("₹","").str.strip().to_list() #replacing rupee sign to empty string

#to find the denominators
text = []
for PriceString in price_colvalues:

    try:
        if (PriceString.split()[1]).isalpha(): #splitting prices "8.11 Lakh" by spaces
            text.append(PriceString.split()[1])
    except:
        pass

print("price denominations >>>>>>>>>>> ",set(text))
# Out:
# price denominations >>>>>>>>>>>  {'Lakh', 'Crore'}

# %%
CroreCarsFrame = new_car_detail[new_car_detail.price.str.contains('Crore')]

# print("Crores Valued Cars Model >>>>>>\n",CroreCarsFrame.model.tolist())
# print("\nCrores Valued Cars Model Year >>>>>>\n",CroreCarsFrame.modelYear.tolist())
# print("\nCrores Valued Cars Model Price >>>>>>\n",CroreCarsFrame.price.tolist())

CroreCarsFrame.loc[:,['place','km','model','modelYear','price']].sort_values(by = 'km').reset_index(drop=True)
# Out:
#         place       km                         model  modelYear         price
# 0       delhi    101.0           Land Rover Defender       2023  ₹ 1.32 Crore
# 1       delhi   1600.0           Land Rover Defender       2023  ₹ 1.32 Crore
# 2       delhi   3500.0       Toyota Land Cruiser 300       2023  ₹ 2.69 Crore
# 3       delhi   3500.0        Mercedes-Benz AMG G 63       2023  ₹ 4.15 Crore
# 4       delhi   4000.0        Mercedes-Benz AMG G 63       2022  ₹ 3.95 Crore
# 5       delhi   7900.0         Mercedes-Benz S-Class       2021  ₹ 1.55 Crore
# 6       delhi   9500.0                        BMW X7       2019  ₹ 1.10 Crore
# 7   bangalore  10000.0                        BMW X7       2022  ₹ 1.30 Crore
# 8       delhi  10500.0               Toyota Vellfire       2023  ₹ 1.19 Crore
# 9     chennai  14000.0         Mercedes-Benz S-Class       2020  ₹ 1.18 Crore
# 10      delhi  16000.0             Mercedes-Benz GLS       2022  ₹ 1.38 Crore
# 11     jaipur  30000.0                   Porsche 911       2020  ₹ 1.50 Crore
# 12    kolkata  30000.0          Mercedes-Benz AMG GT       2016  ₹ 2.10 Crore
# 13  hyderabad  31614.0        Land Rover Range Rover       2020  ₹ 2.60 Crore
# 14      delhi  34000.0         Mercedes-Benz S-Class       2019  ₹ 1.59 Crore
# 15      delhi  35000.0  Land Rover Range Rover Sport       2018  ₹ 1.03 Crore
# 16      delhi  38000.0               Mercedes-Benz G       2021  ₹ 2.45 Crore
# 17     jaipur  44210.0                  BMW 7 Series       2020  ₹ 1.05 Crore
# 18    chennai  52000.0             Mercedes-Benz GLS       2021  ₹ 1.13 Crore
# 19    chennai  68000.0         Mercedes-Benz S-Class       2018  ₹ 1.10 Crore

# %%
lakhCarsFrame = new_car_detail[new_car_detail.price.str.contains('Lakh')]

# print("Crores Valued Cars Model >>>>>>\n",CroreCarsFrame.model.tolist())
# print("\nCrores Valued Cars Model Year >>>>>>\n",CroreCarsFrame.modelYear.tolist())
# print("\nCrores Valued Cars Model Price >>>>>>\n",CroreCarsFrame.price.tolist())

lakhCarsFrame.loc[:,['place','km','model','modelYear','price']].sort_values(by = 'km').reset_index(drop=True)
# Out:
#           place         km                        model  modelYear  \
# 0        jaipur        0.0               Maruti Wagon R       2015
# 1     bangalore      150.0                  MG Comet EV       2023
# 2       kolkata      170.0  BMW 3 Series Gran Limousine       2023
# 3        jaipur      200.0                Hyundai Creta       2023
# 4       chennai      300.0       Mercedes-Benz AMG A 35       2022
# ...         ...        ...                          ...        ...
# 8234    chennai   800000.0         Toyota Innova Crysta       2018
# 8235    kolkata   975000.0                    Kia Sonet       2021
# 8236    chennai  1200000.0             Mahindra Scorpio       2019
# 8237    chennai  2000022.0         Toyota Innova Crysta       2017
# 8238    chennai  5500000.0        Mercedes-Benz C-Class       2018
#
#              price
# 0      ₹ 3.50 Lakh
# 1      ₹ 9.50 Lakh
# 2     ₹ 58.95 Lakh
# 3        ₹ 20 Lakh
# 4        ₹ 59 Lakh
# ...            ...
# 8234  ₹ 21.50 Lakh
# 8235   ₹ 9.75 Lakh
# 8236  ₹ 11.50 Lakh
# 8237  ₹ 17.50 Lakh
# 8238     ₹ 36 Lakh
#
# [8239 rows x 5 columns]

# %% [markdown]
# # *new_car_overview*

# %%
combined_df.new_car_overview
# Out:
# 0       {'heading': 'Car overview', 'top': [{'key': 'R...
# 1       {'heading': 'Car overview', 'top': [{'key': 'R...
# 2       {'heading': 'Car overview', 'top': [{'key': 'R...
# 3       {'heading': 'Car overview', 'top': [{'key': 'R...
# 4       {'heading': 'Car overview', 'top': [{'key': 'R...
#                               ...
# 8364    {'heading': 'Car overview', 'top': [{'key': 'R...
# 8365    {'heading': 'Car overview', 'top': [{'key': 'R...
# 8366    {'heading': 'Car overview', 'top': [{'key': 'R...
# 8367    {'heading': 'Car overview', 'top': [{'key': 'R...
# 8368    {'heading': 'Car overview', 'top': [{'key': 'R...
# Name: new_car_overview, Length: 8369, dtype: object

# %%
def to_get_overview(data):
    return {value['key'] : value['value'] for value in data}

combined_df.new_car_overview =combined_df.new_car_overview.apply(lambda x: to_get_overview(eval(x).get('top')))
new_car_overview = pd.DataFrame(combined_df.new_car_overview.tolist())

# %%
new_car_overview.head()
# Out:
#   Registration Year     Insurance Validity Fuel Type    Seats    Kms Driven  \
# 0              2015  Third Party insurance    Petrol  5 Seats  1,20,000 Kms
# 1          Feb 2018          Comprehensive    Petrol  5 Seats    32,706 Kms
# 2         Sept 2018          Comprehensive    Petrol  5 Seats    11,949 Kms
# 3          Dec 2014          Comprehensive    Petrol  5 Seats    17,794 Kms
# 4              2015  Third Party insurance    Diesel  5 Seats    60,000 Kms
#
#     RTO     Ownership Engine Displacement Transmission  Year of Manufacture
# 0  KA51   Third Owner              998 cc       Manual               2015.0
# 1  KA05  Second Owner             1497 cc       Manual               2018.0
# 2  KA03   First Owner             1199 cc       Manual               2018.0
# 3  KA53   First Owner             1197 cc       Manual               2014.0
# 4  KA04   First Owner             1248 cc       Manual               2015.0

# %%
def to_get_features(data):
    extract = {'Features': [],
               "Comfort": [],
               "Interior":[],
               "Exterior": []
               }

    for features in data['top']:
        extract['Features'].append(features['value'])
    try:
        for comfort in data['data'][0]['list']:
            extract['Comfort'].append(comfort['value'])
    except:
        extract['Comfort'].append('Not-Specified')


    try:
        for interior in data['data'][1]['list']:
            extract['Interior'].append(interior['value'])
    except:
        extract['Interior'].append('Not-Specified')

    try:
        for exterior in data['data'][2]['list']:
            extract['Exterior'].append(exterior['value'])
    except:
        extract['Exterior'].append(None)
    # print(extract)
    return extract

combined_df.new_car_feature = combined_df.new_car_feature.apply(lambda x: to_get_features(eval(x)))
new_car_feature =pd.DataFrame(combined_df.new_car_feature.tolist())
new_car_feature
# Out:
#                                                Features  \
# 0     [Power Steering, Power Windows Front, Air Cond...
# 1     [Power Steering, Power Windows Front, Air Cond...
# 2     [Power Steering, Power Windows Front, Air Cond...
# 3     [Power Steering, Power Windows Front, Air Cond...
# 4     [Power Steering, Power Windows Front, Air Cond...
# ...                                                 ...
# 8364  [Power Steering, Power Windows Front, Air Cond...
# 8365  [Power Steering, Power Windows Front, Air Cond...
# 8366  [Power Steering, Power Windows Front, Air Cond...
# 8367  [Power Steering, Power Windows Front, Air Cond...
# 8368  [Power Steering, Power Windows Front, Air Cond...
#
#                                                 Comfort  \
# 0     [Power Steering, Power Windows Front, Power Wi...
# 1     [Power Steering, Power Windows Front, Power Wi...
# 2     [Power Steering, Power Windows Front, Power Wi...
# 3     [Power Steering, Power Windows Front, Power Wi...
# 4     [Power Steering, Power Windows Front, Power Wi...
# ...                                                 ...
# 8364  [Power Steering, Power Windows Front, Power Wi...
# 8365  [Power Steering, Power Windows Front, Remote T...
# 8366  [Power Steering, Power Windows Front, Power Wi...
# 8367  [Power Steering, Power Windows Front, Power Wi...
# 8368  [Power Steering, Power Windows Front, Power Wi...
#
#                                                Interior  \
# 0     [Air Conditioner, Heater, Digital Odometer, El...
# 1     [Air Conditioner, Heater, Adjustable Steering,...
# 2     [Air Conditioner, Heater, Adjustable Steering,...
# 3     [Air Conditioner, Heater, Adjustable Steering,...
# 4     [Air Conditioner, Heater, Adjustable Steering,...
# ...                                                 ...
# 8364  [Air Conditioner, Heater, Adjustable Steering,...
# 8365  [Air Conditioner, Heater, Digital Odometer, El...
# 8366  [Air Conditioner, Heater, Adjustable Steering,...
# 8367  [Air Conditioner, Heater, Adjustable Steering,...
# 8368  [Air Conditioner, Heater, Adjustable Steering,...
#
#                                                Exterior
# 0     [Adjustable Head Lights, Manually Adjustable E...
# 1     [Adjustable Head Lights, Fog Lights Front, Pow...
# 2     [Adjustable Head Lights, Fog Lights Front, Pow...
# 3     [Adjustable Head Lights, Fog Lights Front, Pow...
# 4     [Adjustable Head Lights, Fog Lights Front, Pow...
# ...                                                 ...
# 8364  [Adjustable Head Lights, Power Adjustable Exte...
# 8365  [Adjustable Head Lights, Manually Adjustable E...
# 8366  [Adjustable Head Lights, Fog Lights Front, Fog...
# 8367  [Adjustable Head Lights, Fog Lights Front, Fog...
# 8368  [Adjustable Head Lights, Fog Lights Front, Pow...
#
# [8369 rows x 4 columns]

# %%
pd.set_option('display.max_columns', 500)

# %%
final_data =pd.concat([new_car_detail, new_car_overview, new_car_feature], axis=1)
final_data.head()
# Out:
#        ft         bt        km transmission  owner      oem  \
# 0  Petrol  Hatchback  120000.0       Manual      3   Maruti
# 1  Petrol        SUV   32706.0       Manual      2     Ford
# 2  Petrol  Hatchback   11949.0       Manual      1     Tata
# 3  Petrol      Sedan   17794.0       Manual      1  Hyundai
# 4  Diesel        SUV   60000.0       Manual      1   Maruti
#
#                 model  modelYear               variantName        price  \
# 0      Maruti Celerio       2015                       VXI     ₹ 4 Lakh
# 1       Ford Ecosport       2018  1.5 Petrol Titanium BSIV  ₹ 8.11 Lakh
# 2          Tata Tiago       2018           1.2 Revotron XZ  ₹ 5.85 Lakh
# 3       Hyundai Xcent       2014        1.2 Kappa S Option  ₹ 4.62 Lakh
# 4  Maruti SX4 S Cross       2015             DDiS 200 Zeta  ₹ 7.90 Lakh
#
#        place Registration Year     Insurance Validity Fuel Type    Seats  \
# 0  bangalore              2015  Third Party insurance    Petrol  5 Seats
# 1  bangalore          Feb 2018          Comprehensive    Petrol  5 Seats
# 2  bangalore         Sept 2018          Comprehensive    Petrol  5 Seats
# 3  bangalore          Dec 2014          Comprehensive    Petrol  5 Seats
# 4  bangalore              2015  Third Party insurance    Diesel  5 Seats
#
#      Kms Driven   RTO     Ownership Engine Displacement Transmission  \
# 0  1,20,000 Kms  KA51   Third Owner              998 cc       Manual
# 1    32,706 Kms  KA05  Second Owner             1497 cc       Manual
# 2    11,949 Kms  KA03   First Owner             1199 cc       Manual
# 3    17,794 Kms  KA53   First Owner             1197 cc       Manual
# 4    60,000 Kms  KA04   First Owner             1248 cc       Manual
#
#    Year of Manufacture                                           Features  \
# 0               2015.0  [Power Steering, Power Windows Front, Air Cond...
# 1               2018.0  [Power Steering, Power Windows Front, Air Cond...
# 2               2018.0  [Power Steering, Power Windows Front, Air Cond...
# 3               2014.0  [Power Steering, Power Windows Front, Air Cond...
# 4               2015.0  [Power Steering, Power Windows Front, Air Cond...
#
#                                              Comfort  \
# 0  [Power Steering, Power Windows Front, Power Wi...
# 1  [Power Steering, Power Windows Front, Power Wi...
# 2  [Power Steering, Power Windows Front, Power Wi...
# 3  [Power Steering, Power Windows Front, Power Wi...
# 4  [Power Steering, Power Windows Front, Power Wi...
#
#                                             Interior  \
# 0  [Air Conditioner, Heater, Digital Odometer, El...
# 1  [Air Conditioner, Heater, Adjustable Steering,...
# 2  [Air Conditioner, Heater, Adjustable Steering,...
# 3  [Air Conditioner, Heater, Adjustable Steering,...
# 4  [Air Conditioner, Heater, Adjustable Steering,...
#
#                                             Exterior
# 0  [Adjustable Head Lights, Manually Adjustable E...
# 1  [Adjustable Head Lights, Fog Lights Front, Pow...
# 2  [Adjustable Head Lights, Fog Lights Front, Pow...
# 3  [Adjustable Head Lights, Fog Lights Front, Pow...
# 4  [Adjustable Head Lights, Fog Lights Front, Pow...

# %%
final_data.isna().sum()
# Out:
# ft                       0
# bt                       0
# km                       0
# transmission             0
# owner                    0
# oem                      0
# model                    0
# modelYear                0
# variantName              0
# price                    0
# place                    0
# Registration Year       52
# Insurance Validity       4
# Fuel Type                0
# Seats                    6
# Kms Driven               2
# RTO                    888
# Ownership               32
# Engine Displacement      4
# Transmission             0
# Year of Manufacture     20
# Features                 0
# Comfort                  0
# Interior                 0
# Exterior                 0
# dtype: int64

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ft                   8369 non-null   object
#  1   bt                   8369 non-null   object
#  2   km                   8369 non-null   float64
#  3   transmission         8369 non-null   object
#  4   owner                8369 non-null   int64
#  5   oem                  8369 non-null   object
#  6   model                8369 non-null   object
#  7   modelYear            8369 non-null   int64
#  8   variantName          8369 non-null   object
#  9   price                8369 non-null   object
#  10  place                8369 non-null   object
#  11  Registration Year    8317 non-null   object
#  12  Insurance Validity   8365 non-null   object
#  13  Fuel Type            8369 non-null   object
#  14  Seats                8363 non-null   object
#  15  Kms Driven           8367 non-null   object
#  16  RTO                  7481 non-null   object
#  17  Ownership            8337 non-null   object
#  18  Engine Displacement  8365 non-null   object
#  19  Transmission         8369 non-null   object
#  20  Year of Manufacture  8349 non-null   float64
#  21  Features             8369 non-null   object
#  22  Comfort              8369 non-null   object
#  23  Interior             8369 non-null   object
#  24  Exterior             8369 non-null   object
# dtypes: float64(2), int64(2), object(21)
# memory usage: 1.6+ MB

# %%
for i in final_data.columns:
    # print(i)
    if i not in ['Features','Comfort', 'Interior', 'Exterior', 'trendingText']:
        print(i, final_data[i].nunique())
# Out:
# ft 5
# bt 11
# km 4090
# transmission 2
# owner 6
# oem 33
# model 315
# modelYear 29
# variantName 2157
# price 1400
# place 6
# Registration Year 233
# Insurance Validity 7
# Fuel Type 5
# Seats 8
# Kms Driven 4089
# RTO 465
# Ownership 5
# Engine Displacement 150
# Transmission 2
# Year of Manufacture 22

# %%
final_data.isna().sum()
# Out:
# ft                       0
# bt                       0
# km                       0
# transmission             0
# owner                    0
# oem                      0
# model                    0
# modelYear                0
# variantName              0
# price                    0
# place                    0
# Registration Year       52
# Insurance Validity       4
# Fuel Type                0
# Seats                    6
# Kms Driven               2
# RTO                    888
# Ownership               32
# Engine Displacement      4
# Transmission             0
# Year of Manufacture     20
# Features                 0
# Comfort                  0
# Interior                 0
# Exterior                 0
# dtype: int64

# %%
import pandas as pd

# Assuming 'Registration Year' is the column name
final_data['Registration Year'] = final_data['Registration Year'].str.extract(r'(\d{4})')

# Print the updated column
print(final_data['Registration Year'])
# Out:
# 0       2015
# 1       2018
# 2       2018
# 3       2014
# 4       2015
#         ...
# 8364    2022
# 8365    2014
# 8366    2011
# 8367    2012
# 8368    2017
# Name: Registration Year, Length: 8369, dtype: object

# %%
final_data['Registration Year'].value_counts()
# Out:
# 2018    979
# 2017    938
# 2016    801
# 2019    799
# 2021    690
# 2020    640
# 2014    592
# 2022    571
# 2015    570
# 2013    383
# 2012    332
# 2011    274
# 2010    246
# 2009    141
# 2023    116
# 2008     81
# 2007     54
# 2006     42
# 2004     25
# 2005     20
# 2003     13
# 2002     10
# Name: Registration Year, dtype: int64

# %%
final_data.drop(columns=['Registration Year'], inplace=True)

# %%
final_data['Insurance Validity'].value_counts()
# Out:
# Third Party insurance    4055
# Comprehensive            3150
# Third Party               630
# Zero Dep                  303
# Not Available             223
# 1                           3
# 2                           1
# Name: Insurance Validity, dtype: int64

# %%
final_data['Insurance Validity'].fillna(final_data['Insurance Validity'].mode()[0], inplace=True)

# %%
final_data.Seats.value_counts()
# Out:
# 5 Seats     7354
# 7 Seats      728
# 6 Seats      103
# 4 Seats       93
# 8 Seats       62
# 9 Seats       11
# 2 Seats        7
# 10 Seats       5
# Name: Seats, dtype: int64

# %%
final_data['Seats'].fillna(final_data['Seats'].mode()[0], inplace=True)

# %%
final_data.drop(columns=['RTO'], inplace=True)

# %%
final_data.Ownership.value_counts()
# Out:
# First Owner     5882
# Second Owner    1982
# Third Owner      374
# Fourth Owner      80
# Fifth Owner       19
# Name: Ownership, dtype: int64

# %%
final_data['Ownership'].fillna(final_data['Ownership'].mode()[0], inplace=True)

# %%
final_data['Year of Manufacture'].value_counts()
# Out:
# 2018.0    980
# 2017.0    945
# 2016.0    815
# 2019.0    789
# 2021.0    686
# 2020.0    612
# 2015.0    605
# 2014.0    588
# 2022.0    563
# 2013.0    400
# 2012.0    339
# 2011.0    272
# 2010.0    254
# 2009.0    144
# 2023.0    104
# 2008.0     85
# 2007.0     56
# 2006.0     44
# 2004.0     25
# 2005.0     20
# 2003.0     13
# 2002.0     10
# Name: Year of Manufacture, dtype: int64

# %%
final_data['Year of Manufacture'].fillna(final_data['Year of Manufacture'].mode()[0], inplace=True)

# %%
final_data['Engine Displacement'].value_counts()
# Out:
# 1197 cc    1607
# 998 cc      640
# 1199 cc     489
# 1497 cc     451
# 1248 cc     424
#            ...
# 1468 cc       1
# 2997 cc       1
# 2894 cc       1
# 3346 cc       1
# 2489 cc       1
# Name: Engine Displacement, Length: 150, dtype: int64

# %%
final_data['Engine Displacement'].fillna(final_data['Engine Displacement'].mode()[0], inplace=True)

# %%
final_data.isnull().sum()
# Out:
# ft                     0
# bt                     0
# km                     0
# transmission           0
# owner                  0
# oem                    0
# model                  0
# modelYear              0
# variantName            0
# price                  0
# place                  0
# Insurance Validity     0
# Fuel Type              0
# Seats                  0
# Kms Driven             2
# Ownership              0
# Engine Displacement    0
# Transmission           0
# Year of Manufacture    0
# Features               0
# Comfort                0
# Interior               0
# Exterior               0
# dtype: int64

# %%
final_data.drop(['Kms Driven','Ownership'],axis = 1,inplace = True)

# %%
final_data.head(1)
# Out:
#        ft         bt        km transmission  owner     oem           model  \
# 0  Petrol  Hatchback  120000.0       Manual      3  Maruti  Maruti Celerio
#
#    modelYear variantName     price      place     Insurance Validity  \
# 0       2015         VXI  ₹ 4 Lakh  bangalore  Third Party insurance
#
#   Fuel Type    Seats Engine Displacement Transmission  Year of Manufacture  \
# 0    Petrol  5 Seats              998 cc       Manual               2015.0
#
#                                             Features  \
# 0  [Power Steering, Power Windows Front, Air Cond...
#
#                                              Comfort  \
# 0  [Power Steering, Power Windows Front, Power Wi...
#
#                                             Interior  \
# 0  [Air Conditioner, Heater, Digital Odometer, El...
#
#                                             Exterior
# 0  [Adjustable Head Lights, Manually Adjustable E...

# %%
final_data['Seats'] = final_data['Seats'].str.extract('(\d+)').astype(float)


final_data['Engine Displacement'] = final_data['Engine Displacement'].str.extract('(\d+)').astype(float)

# %%
final_data.ft.value_counts()
# Out:
# Petrol      5554
# Diesel      2673
# Cng           98
# Electric      28
# Lpg           16
# Name: ft, dtype: int64

# %%
final_data.bt.value_counts()
# Out:
# Hatchback        3567
# SUV              2225
# Sedan            2174
# MUV               352
# Minivans           23
# Coupe              10
# Pickup Trucks       6
# Convertibles        6
#                     4
# Hybrids             1
# Wagon               1
# Name: bt, dtype: int64

# %%
final_data.km.value_counts()
# Out:
# 120000.0    315
# 50000.0     263
# 70000.0     262
# 60000.0     259
# 30000.0     253
#            ...
# 52802.0       1
# 46830.0       1
# 70038.0       1
# 15957.0       1
# 151000.0      1
# Name: km, Length: 4090, dtype: int64

# %%
final_data.transmission.value_counts()
# Out:
# Manual       6052
# Automatic    2317
# Name: transmission, dtype: int64

# %%
final_data.owner.value_counts()
# Out:
# 1    5882
# 2    1982
# 3     374
# 4      80
# 0      32
# 5      19
# Name: owner, dtype: int64

# %%
final_data.oem.value_counts()
# Out:
# Maruti                2252
# Hyundai               1651
# Honda                  865
# Tata                   431
# Mahindra               377
# Toyota                 325
# Renault                312
# Ford                   311
# Volkswagen             294
# Mercedes-Benz          245
# BMW                    184
# Skoda                  161
# Kia                    158
# Audi                   156
# Jeep                   112
# MG                      90
# Nissan                  78
# Chevrolet               76
# Datsun                  74
# Land Rover              44
# Volvo                   41
# Jaguar                  35
# Fiat                    31
# Mitsubishi              14
# Mini                    12
# Citroen                  8
# Porsche                  6
# Lexus                    5
# Mahindra Renault         5
# Isuzu                    5
# Mahindra Ssangyong       4
# Hindustan Motors         4
# Opel                     3
# Name: oem, dtype: int64

# %%
final_data.model.value_counts()
# Out:
# Honda City                       370
# Maruti Swift                     350
# Hyundai i20                      331
# Maruti Baleno                    295
# Hyundai Grand i10                260
#                                 ...
# Toyota Land Cruiser 300            1
# Mercedes-Benz SLC                  1
# Maruti FRONX                       1
# Maruti Celerio Tour 2018-2021      1
# Jaguar F-TYPE                      1
# Name: model, Length: 315, dtype: int64

# %%
final_data.modelYear.value_counts()
# Out:
# 2018    980
# 2017    945
# 2016    815
# 2019    789
# 2021    686
# 2020    612
# 2015    605
# 2014    588
# 2022    563
# 2013    400
# 2012    339
# 2011    272
# 2010    254
# 2009    144
# 2023    104
# 2008     85
# 2007     56
# 2006     44
# 2004     25
# 2005     20
# 2003     13
# 2002     10
# 2001      9
# 1998      3
# 1995      2
# 1985      2
# 1999      2
# 2000      1
# 1997      1
# Name: modelYear, dtype: int64

# %%
final_data.variantName.value_counts()
# Out:
# VXI                     337
# LXI                     145
# Sportz                   97
# VDI                      78
# Magna                    77
#                        ...
# S Plus i-VTEC             1
# VXi Option SHVS           1
# XZA Plus (O) AT BSVI      1
# 40TFSI Quattro            1
# C 200 CGI Elegance        1
# Name: variantName, Length: 2157, dtype: int64

# %%
final_data.price.value_counts()
# Out:
# ₹ 6.50 Lakh     106
# ₹ 4.50 Lakh      98
# ₹ 5 Lakh         97
# ₹ 3 Lakh         97
# ₹ 4 Lakh         90
#                ...
# ₹ 21.25 Lakh      1
# ₹ 89 Lakh         1
# ₹ 13.28 Lakh      1
# ₹ 13.10 Lakh      1
# ₹ 10.82 Lakh      1
# Name: price, Length: 1400, dtype: int64

# %%
import re

# Assuming 'price' is the column name
def convert_price(value):
    if 'Lakh' in value:
        value = re.sub(r'[^\d.]', '', value)  # Remove non-numeric characters except '.'
        value = float(value) * 100000  # 1 Lakh = 100,000
    elif 'Crore' in value:
        value = re.sub(r'[^\d.]', '', value)  # Remove non-numeric characters except '.'
        value = float(value) * 10000000  # 1 Crore = 10,000,000
    else:
        value = re.sub(r'[^\d.]', '', value)  # Remove non-numeric characters except '.'
        value = float(value)
    return value

final_data['price'] = final_data['price'].apply(convert_price)

# %%
final_data.price.value_counts()
# Out:
# 650000.0     106
# 450000.0      98
# 500000.0      97
# 300000.0      97
# 400000.0      90
#             ...
# 2125000.0      1
# 8900000.0      1
# 1328000.0      1
# 1310000.0      1
# 1082000.0      1
# Name: price, Length: 1400, dtype: int64

# %%
final_data.place.value_counts()
# Out:
# delhi        1485
# hyderabad    1483
# bangalore    1481
# chennai      1419
# kolkata      1381
# jaipur       1120
# Name: place, dtype: int64

# %%
final_data['Insurance Validity'].value_counts()
# Out:
# Third Party insurance    4059
# Comprehensive            3150
# Third Party               630
# Zero Dep                  303
# Not Available             223
# 1                           3
# 2                           1
# Name: Insurance Validity, dtype: int64

# %%
final_data['Fuel Type'].value_counts()
# Out:
# Petrol      5554
# Diesel      2673
# CNG           98
# Electric      28
# LPG           16
# Name: Fuel Type, dtype: int64

# %%
final_data['Seats'].value_counts()
# Out:
# 5.0     7360
# 7.0      728
# 6.0      103
# 4.0       93
# 8.0       62
# 9.0       11
# 2.0        7
# 10.0       5
# Name: Seats, dtype: int64

# %%
final_data['Engine Displacement'].value_counts()
# Out:
# 1197.0    1611
# 998.0      640
# 1199.0     489
# 1497.0     451
# 1248.0     424
#           ...
# 1468.0       1
# 2997.0       1
# 2894.0       1
# 3346.0       1
# 2489.0       1
# Name: Engine Displacement, Length: 150, dtype: int64

# %%
final_data['Transmission'].value_counts()
# Out:
# Manual       6052
# Automatic    2317
# Name: Transmission, dtype: int64

# %%
final_data['Year of Manufacture'].value_counts()
# Out:
# 2018.0    1000
# 2017.0     945
# 2016.0     815
# 2019.0     789
# 2021.0     686
# 2020.0     612
# 2015.0     605
# 2014.0     588
# 2022.0     563
# 2013.0     400
# 2012.0     339
# 2011.0     272
# 2010.0     254
# 2009.0     144
# 2023.0     104
# 2008.0      85
# 2007.0      56
# 2006.0      44
# 2004.0      25
# 2005.0      20
# 2003.0      13
# 2002.0      10
# Name: Year of Manufacture, dtype: int64

# %%
final_data['Features'].value_counts()
# Out:
# [Power Steering, Power Windows Front, Air Conditioner, Heater, Adjustable Head Lights, Fog Lights Front, Anti Lock Braking System, Centeral Locking, Cd Player]                                  1600
# [Power Steering, Power Windows Front, Air Conditioner, Heater, Adjustable Head Lights, Fog Lights Front, Anti Lock Braking System, Centeral Locking, Radio]                                      1357
# [Power Steering, Power Windows Front, Air Conditioner, Heater, Adjustable Head Lights, Fog Lights Front, Anti Lock Braking System, Brake Assist, Cd Player]                                       916
# [Power Steering, Power Windows Front, Air Conditioner, Heater, Adjustable Head Lights, Fog Lights Front, Anti Lock Braking System, Brake Assist, Radio]                                           646
# [Power Steering, Power Windows Front, Air Conditioner, Heater, Adjustable Head Lights, Power Adjustable Exterior Rear View Mirror, Anti Lock Braking System, Centeral Locking, Radio]             453
#                                                                                                                                                                                                  ...
# [Power Steering, Power Windows Front, Air Conditioner, Adjustable Steering, Adjustable Head Lights, Fog Lights Front, Anti Lock Braking System, Brake Assist, Radio]                                1
# [Power Steering, Multifunction Steering Wheel, Adjustable Steering, Leather Steering Wheel, Sun Roof, Moon Roof, Driver Air Bag, Side Air Bag Front, Touch Screen]                                  1
#
#                                             Features  \
# 0  [Power Steering, Power Windows Front, Air Cond...
#
#                                              Comfort  \
# 0  [Power Steering, Power Windows Front, Power Wi...
#
#                                             Interior  \
# 0  [Air Conditioner, Heater, Digital Odometer, El...
#
#                                             Exterior
# 0  [Adjustable Head Lights, Manually Adjustable E...

# %%
final_data.info()               #   km, price, Seats, Engine Displacement, Year of Manufacture,
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ft                   8369 non-null   object
#  1   bt                   8369 non-null   object
#  2   km                   8369 non-null   float64
#  3   transmission         8369 non-null   object
#  4   owner                8369 non-null   int64
#  5   oem                  8369 non-null   object
#  6   model                8369 non-null   object
#  7   modelYear            8369 non-null   int64
#  8   variantName          8369 non-null   object
#  9   price                8369 non-null   float64
#  10  place                8369 non-null   object
#  11  Insurance Validity   8369 non-null   object
#  12  Fuel Type            8369 non-null   object
#  13  Seats                8369 non-null   float64
#  14  Engine Displacement  8369 non-null   float64
#  15  Transmission         8369 non-null   object
#  16  Year of Manufacture  8369 non-null   float64
#  17  Features             8369 non-null   object
#  18  Comfort              8369 non-null   object
#  19  Interior             8369 non-null   object
#  20  Exterior             8369 non-null   object
# dtypes: float64(5), int64(2), object(14)
# memory usage: 1.3+ MB

# %%
# Assuming 'km', 'price', 'Seats', 'Engine Displacement', 'Year of Manufacture' are the column names
final_data['km'] = final_data['km'].astype(int)
final_data['price'] = final_data['price'].astype(int)
final_data['Seats'] = final_data['Seats'].astype(int)
final_data['Engine Displacement'] = final_data['Engine Displacement'].astype(int)
final_data['Year of Manufacture'] = final_data['Year of Manufacture'].astype(int)

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ft                   8369 non-null   object
#  1   bt                   8369 non-null   object
#  2   km                   8369 non-null   int64
#  3   transmission         8369 non-null   object
#  4   owner                8369 non-null   int64
#  5   oem                  8369 non-null   object
#  6   model                8369 non-null   object
#  7   modelYear            8369 non-null   int64
#  8   variantName          8369 non-null   object
#  9   price                8369 non-null   int64
#  10  place                8369 non-null   object
#  11  Insurance Validity   8369 non-null   object
#  12  Fuel Type            8369 non-null   object
#  13  Seats                8369 non-null   int64
#  14  Engine Displacement  8369 non-null   int64
#  15  Transmission         8369 non-null   object
#  16  Year of Manufacture  8369 non-null   int64
#  17  Features             8369 non-null   object
#  18  Comfort              8369 non-null   object
#  19  Interior             8369 non-null   object
#  20  Exterior             8369 non-null   object
# dtypes: int64(7), object(14)
# memory usage: 1.3+ MB

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**

# %% [markdown]
# distribution of all columns

# %%
ft_counts = final_data['ft'].value_counts()

# Plotting the bar plot
plt.figure(figsize=(10, 6))
ft_counts.plot(kind='bar')
plt.title('Frequency of ft Values')
plt.xlabel('ft')
plt.ylabel('Frequency')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
# Assuming 'ft' is the column name
ft_counts = final_data['bt'].value_counts()

# Plotting the bar plot
plt.figure(figsize=(10, 6))
ft_counts.plot(kind='bar')
plt.title('Frequency of ft Values')
plt.xlabel('bt')
plt.ylabel('Frequency')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(final_data['km'], bins=20, color='skyblue', edgecolor='black')  # Adjust the number of bins as needed
plt.title('Histogram of km')
plt.xlabel('Kilometers Driven')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
columns_to_check = ['Year of Manufacture']

for column in columns_to_check:
    plt.figure(figsize=(10, 6))
    plt.hist2d(final_data[column], final_data['km'], bins=20, cmap='Blues')
    plt.colorbar(label='Frequency')
    plt.title(f'Histogram of km vs {column}')
    plt.xlabel(column)
    plt.ylabel('Kilometers Driven')
    plt.show()

# %%
ft_counts = final_data['transmission'].value_counts()

# Plotting the bar plot
plt.figure(figsize=(10, 6))
ft_counts.plot(kind='bar')
plt.title('Frequency of transmission Values')
plt.xlabel('transmission')
plt.ylabel('Frequency')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
ft_counts = final_data['owner'].value_counts()

# Plotting the bar plot
plt.figure(figsize=(10, 6))
ft_counts.plot(kind='bar')
plt.title('Frequency of owner Values')
plt.xlabel('owner')
plt.ylabel('Frequency')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
ft_counts = final_data['oem'].value_counts()

# Plotting the bar plot
plt.figure(figsize=(10, 6))
ft_counts.plot(kind='bar')
plt.title('Frequency of oem Values')
plt.xlabel('oem')
plt.ylabel('Frequency')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named 'final_data'

# List of numeric columns
numeric_columns = ['km', 'price', 'Seats', 'Engine Displacement', 'Year of Manufacture']

# List of categorical columns
categorical_columns = ['ft', 'bt', 'transmission', 'owner', 'oem', 'model', 'modelYear', 'variantName', 'place',
                       'Insurance Validity', 'Fuel Type', 'Transmission']

# Plot histograms for numeric columns
for column in numeric_columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(final_data[column], kde=True, color='skyblue', edgecolor='black')
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

# Plot count plots for categorical columns
for column in categorical_columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=final_data, x=column, palette='viridis')
    plt.title(f'Count Plot of {column}')
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.show()
# Out:
# <ipython-input-90-837d08c326c5>:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=final_data, x=column, palette='viridis')
# <ipython-input-90-837d08c326c5>:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=final_data, x=column, palette='viridis')
# <ipython-input-90-837d08c326c5>:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=final_data, x=column, palette='viridis')
# <ipython-input-90-837d08c326c5>:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=final_data, x=column, palette='viridis')
# <ipython-input-90-837d08c326c5>:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=final_data, x=column, palette='viridis')
# <ipython-input-90-837d08c326c5>:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=final_data, x=column, palette='viridis')
# <ipython-input-90-837d08c326c5>:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=final_data, x=column, palette='viridis')
# <ipython-input-90-837d08c326c5>:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=final_data, x=column, palette='viridis')
# <ipython-input-90-837d08c326c5>:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=final_data, x=column, palette='viridis')
# <ipython-input-90-837d08c326c5>:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=final_data, x=column, palette='viridis')
# <ipython-input-90-837d08c326c5>:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=final_data, x=column, palette='viridis')
# <ipython-input-90-837d08c326c5>:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=final_data, x=column, palette='viridis')

# %%
final_data.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ft                   8369 non-null   object
#  1   bt                   8369 non-null   object
#  2   km                   8369 non-null   int64
#  3   transmission         8369 non-null   object
#  4   owner                8369 non-null   int64
#  5   oem                  8369 non-null   object
#  6   model                8369 non-null   object
#  7   modelYear            8369 non-null   int64
#  8   variantName          8369 non-null   object
#  9   price                8369 non-null   int64
#  10  place                8369 non-null   object
#  11  Insurance Validity   8369 non-null   object
#  12  Fuel Type            8369 non-null   object
#  13  Seats                8369 non-null   int64
#  14  Engine Displacement  8369 non-null   int64
#  15  Transmission         8369 non-null   object
#  16  Year of Manufacture  8369 non-null   int64
#  17  Features             8369 non-null   object
#  18  Comfort              8369 non-null   object
#  19  Interior             8369 non-null   object
#  20  Exterior             8369 non-null   object
# dtypes: int64(7), object(14)
# memory usage: 1.3+ MB

# %% [markdown]
# **VS PLOT**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named 'final_data'

# List of categorical columns
categorical_columns = ['ft', 'bt', 'transmission', 'owner', 'oem', 'modelYear']

# Plot violin plots for categorical columns vs price
for column in categorical_columns:
    plt.figure(figsize=(12, 6))
    sns.violinplot(x=final_data[column], y=final_data['price'], palette='muted', inner='quartile')
    plt.title(f'Violin plot of price vs {column}')
    plt.xlabel(column)
    plt.ylabel('Price')
    plt.xticks(rotation=45)
    plt.show()
# Out:
# <ipython-input-93-becf4fb901f7>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=final_data[column], y=final_data['price'], palette='muted', inner='quartile')
# <ipython-input-93-becf4fb901f7>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=final_data[column], y=final_data['price'], palette='muted', inner='quartile')
# <ipython-input-93-becf4fb901f7>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=final_data[column], y=final_data['price'], palette='muted', inner='quartile')
# <ipython-input-93-becf4fb901f7>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=final_data[column], y=final_data['price'], palette='muted', inner='quartile')
# <ipython-input-93-becf4fb901f7>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=final_data[column], y=final_data['price'], palette='muted', inner='quartile')
# <ipython-input-93-becf4fb901f7>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=final_data[column], y=final_data['price'], palette='muted', inner='quartile')

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=final_data['place'], y=final_data['price'], palette='muted')
plt.title('Bar plot of price vs place')
plt.xlabel('Place')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-94-71e7ce56056e>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=final_data['place'], y=final_data['price'], palette='muted')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named 'final_data'

# Sort the DataFrame by 'price' column in ascending order
sorted_final_data = final_data.sort_values(by='price')

plt.figure(figsize=(12, 6))
sns.barplot(x=sorted_final_data['place'], y=sorted_final_data['price'], palette='muted')
plt.title('Bar plot of price vs place (ascending order)')
plt.xlabel('Place')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-101-6275405e81b2>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sorted_final_data['place'], y=sorted_final_data['price'], palette='muted')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named 'final_data'

plt.figure(figsize=(12, 6))
sns.barplot(x=final_data['Insurance Validity'], y=final_data['price'], palette='muted')
plt.title('Bar plot of price vs Insurance Validity')
plt.xlabel('Insurance Validity')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-95-4876bde2dff7>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=final_data['Insurance Validity'], y=final_data['price'], palette='muted')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named 'final_data'

plt.figure(figsize=(12, 6))
sns.barplot(x=final_data['Fuel Type'], y=final_data['price'], palette='muted')
plt.title('Bar plot of price vs Fuel Type')
plt.xlabel('Fuel Type')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-96-23250a4feb38>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=final_data['Fuel Type'], y=final_data['price'], palette='muted')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named 'final_data'

plt.figure(figsize=(12, 6))
sns.barplot(x=final_data['Transmission'], y=final_data['price'], palette='muted')
plt.title('Bar plot of price vs Transmission')
plt.xlabel('Transmission')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-97-613f7b5ebf69>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=final_data['Transmission'], y=final_data['price'], palette='muted')

# %%
# Get the top 10 most frequent models
top_10_models = final_data['model'].value_counts().head(10).index.tolist()

# Filter the DataFrame for only the top 10 models
top_10_data = final_data[final_data['model'].isin(top_10_models)]

# Plotting
plt.figure(figsize=(12, 6))
sns.violinplot(x='model', y='price', data=top_10_data, palette='muted')
plt.title('Violin plot of price vs top 10 models')
plt.xlabel('Model')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-102-3097f1c36520>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='model', y='price', data=top_10_data, palette='muted')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named 'final_data'

# List of numeric columns
numeric_columns = ['km', 'Seats', 'Engine Displacement', 'Year of Manufacture']

# Plot scatter plots for numeric columns
for column in numeric_columns:
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x=final_data[column], y=final_data['price'], color='skyblue')
    plt.title(f'Scatter plot of price vs {column}')
    plt.xlabel(column)
    plt.ylabel('Price')
    plt.grid(True)
    plt.show()
